# %% [markdown]
# # Homework 5
#
# ## Nhi Nguyen 76164237

# %% [markdown]
# In this homework, you're required to follow the basic [tutorial of Seaborn](https://seaborn.pydata.org/tutorial/function_overview.html), and explore the (most) classical dataset of [iris flower](https://en.wikipedia.org/wiki/Iris_flower_data_set).
#
# Prior to start, please make sure that your Seaborn is upgraded to latest version. You can simply try (can also use conda in command line if you like -- only make sure to use the 0.11.1 version or later):

# %%
pip install seaborn --upgrade
# Out:
# Requirement already up-to-date: seaborn in c:\users\nhing\anaconda3\lib\site-packages (0.11.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied, skipping upgrade: pandas>=0.23 in c:\users\nhing\anaconda3\lib\site-packages (from seaborn) (1.1.3)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.2 in c:\users\nhing\anaconda3\lib\site-packages (from seaborn) (3.3.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in c:\users\nhing\anaconda3\lib\site-packages (from seaborn) (1.19.2)
# Requirement already satisfied, skipping upgrade: scipy>=1.0 in c:\users\nhing\anaconda3\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\nhing\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\nhing\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2020.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\nhing\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in c:\users\nhing\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.0.1)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in c:\users\nhing\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2020.6.20)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\nhing\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in c:\users\nhing\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\nhing\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->seaborn) (1.15.0)

# %% [markdown]
# and then **restart the kernel**. Make sure the version is >= 0.11.1

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.1'

# %% [markdown]
# You can also use the following code to set the theme of images.

# %%
sns.set_theme()

# %% [markdown]
# ## Task 1: Load the Iris Dataset
#
# Please follow the instructions below:
#
# 1. Download the "iris.csv" file from canvas, and use `pandas` to load the dataset
#
# 2. Delete (drop) the column named `Id` (note the capital letter **I** here). *Hint: you may find the "inplace" parameter useful in the `drop` method*.
#
# 3. Show the 10 random sampled observations (rows in the data)
#
# 4. Generate the descriptive statistics of the dataset (It's OK to only include numerical variables) *Hint: use the `describe` method*

# %%
import pandas as pd
iris = pd.read_csv ('iris.csv')
iris.drop (columns = "Id", inplace = True)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Task 2: Using Seaborn to visualize the data
#
# - Reproduce the three figures below using seaborn command. Be careful about the labels on the x or y axis (you should select the same variables in iris dataset)
#
# - After each code block of generating figures, write a short paragraph in *Markdown* format about:
#
#     1) what does the figure represent, for example, "it is a histogram that ....", and what does x label and y label refers to.
#
#     2) what basic conclusion about the dataset you can draw from the figure. It does not have to be the rigorous conclusions -- some simple qualitative descriptions are enough. Just imagine you're writing a thesis about iris flower using the data!
#
#
# *Hint:* All the useful codes are included in this basic [tutorial](https://seaborn.pydata.org/tutorial/function_overview.html).

# %% [markdown]
# ### Figure 1

# %%
data=iris
seaborn=sns.load_dataset("iris")
sns.histplot (data = iris, x = "SepalWidthCm", hue = "Species", multiple = "stack")
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %% [markdown]
# This is a stacked bar graph that reflects the amount and the Sepal width of the species reported in the table in Task 1. The x-axis refers to the Sepal widths of the species in cm, the y-axis refers to the amount of each species there are, and the colors (blue, orange, and green) labels what kind of species are being reported on.

# %% [markdown]
# ### Figure 2

# %%
sns.kdeplot(data = iris, x = "PetalLengthCm", hue = "Species", multiple = "stack")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %% [markdown]
# This is a area chart that reflects the densities and the Petal lengths of the species reported in the table in Task 1. The x-axis refers to the Petal lengths of the species in cm, the y-axis refers to their densities, and the colors (blue, orange, and green) labels what kind of species are being reported on.

# %% [markdown]
# ### Figure 3

# %%
sns.pairplot(data = iris, hue = "Species")

# %% [markdown]
# This is a 4x4 plot that reflects pairwise relationships. Each variable is shared in the x-axis across the row and y-axis across the column. The x and y axis records the Petal lengths and widths, as well as the Sepal lengths and widths (all in cm) of the species. The colors (blue, orange, and green) labels what kind of species are being reported on.

# %% [markdown]
# ## Optional Task (Not Graded)
#
# Refer to the [gallery](https://seaborn.pydata.org/examples/index.html) or [other tutorials](https://seaborn.pydata.org/tutorial.html) on the website, and generate more fancy figures with this dataset!

# %%
sns.relplot(x = "SepalLengthCm", y = "SepalWidthCm", hue = "Species", size = "PetalWidthCm", data = iris)

# %% [markdown]
# This is a Scatterplot that plots data in the table in Task 1. It records the species' Sepal lengths and widths, as well as their Petal Widths. The x-axis reflects the species' Sepal lengths, in cm. The y-axis reports the species' Sepal widths, in cm. The size of each dot reflects their Petal widths, in cm, and the colors (blue, orange, green) reflects the type of species they are.

# %%
sns.boxenplot( x="Species", y = "PetalLengthCm", scale="linear", data = iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
# This is a plot that shows the variations of the Petal Lengths of each species in the table of Task 1. The y-axis reflects the Petal lengths of each species and where they range, and the x-axis and color (blue, orange, green) reflects the type of species that are being reported
